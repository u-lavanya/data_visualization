# %%
import pandas as pd

# %%
df=pd.read_csv("world_population (1).csv",index_col=0)

# %%
#display the top5 rows of the dataset

# %%
df.head(10)
#displays the first 10 rows
# Out:
#                      Country Code  \
# Country Name
# Aruba                         ABW
# Andorra                       AND
# Afghanistan                   AFG
# Angola                        AGO
# Albania                       ALB
# Arab World                    ARB
# United Arab Emirates          ARE
# Argentina                     ARG
# Armenia                       ARM
# American Samoa                ASM
#
#                                                          Indicator Name  \
# Country Name
# Aruba                 Population density (people per sq. km of land ...
# Andorra               Population density (people per sq. km of land ...
# Afghanistan           Population density (people per sq. km of land ...
# Angola                Population density (people per sq. km of land ...
# Albania               Population density (people per sq. km of land ...
# Arab World            Population density (people per sq. km of land ...
# ...

# %%
#to display the last 10 rows we use tail
df.tail(10)
# Out:
#                    Country Code  \
# Country Name
# Vietnam                     VNM
# Vanuatu                     VUT
# West Bank and Gaza          PSE
# World                       WLD
# Samoa                       WSM
# Yemen, Rep.                 YEM
# South Africa                ZAF
# Congo, Dem. Rep.            COD
# Zambia                      ZMB
# Zimbabwe                    ZWE
#
#                                                        Indicator Name  \
# Country Name
# Vietnam             Population density (people per sq. km of land ...
# Vanuatu             Population density (people per sq. km of land ...
# West Bank and Gaza  Population density (people per sq. km of land ...
# World               Population density (people per sq. km of land ...
# Samoa               Population density (people per sq. km of land ...
# Yemen, Rep.         Population density (people per sq. km of land ...
# South Africa        Population density (people per sq. km of land ...
# ...

# %%
#to know number of rows and column alone in our dataset
df.shape
# Out:
# (264, 60)

# %%
#we can do all this operations using numpy why we use pandas specially - numpy is only for numeric data,and computational speed is less comapred to pandas 
#numpy is good with small dataset and not large dataset

# %%
#mean for the column 1962 population
df['1962'].mean()
# Out:
# 180.70323050794585

# %%
#mean for the column 2003 population
df['2003'].mean()
# Out:
# 315.84761335407336

# %%
#display the first two rows of dataset
df[0:2]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Aruba                 ABW  Population density (people per sq. km of land ...
# Andorra               AND  Population density (people per sq. km of land ...
#
#              Indicator Code  1960        1961        1962        1963  \
# Country Name
# Aruba           EN.POP.DNST   NaN  307.972222  312.366667  314.983333
# Andorra         EN.POP.DNST   NaN   30.587234   32.714894   34.914894
#
#                     1964        1965        1966  ...        2007        2008  \
# Country Name                                      ...
# Aruba         316.827778  318.666667  320.622222  ...  562.322222  563.011111
# Andorra        37.170213   39.470213   41.800000  ...  180.591489  182.161702
#
#                     2009        2010        2011        2012        2013  \
# Country Name
# Aruba         563.422222  564.427778  566.311111  568.850000  571.783333
# ...

# %%
df[-1:]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Zimbabwe              ZWE  Population density (people per sq. km of land ...
#
#              Indicator Code  1960       1961       1962       1963       1964  \
# Country Name
# Zimbabwe        EN.POP.DNST   NaN  10.021037  10.356112  10.703901  11.062585
#
#                    1965       1966  ...       2007       2008      2009  \
# Country Name                        ...
# Zimbabwe      11.431128  11.809022  ...  34.374559  34.885516  35.46852
#
#                    2010       2011       2012       2013       2014  \
# Country Name
# Zimbabwe      36.122262  36.850438  37.651498  38.511289  39.410249
#
#                    2015  2016
# Country Name
# Zimbabwe      40.332819   NaN
#
# [1 rows x 60 columns]

# %%
df.iloc[-1]
# Out:
# Country Code                                                    ZWE
# Indicator Name    Population density (people per sq. km of land ...
# Indicator Code                                          EN.POP.DNST
# 1960                                                            NaN
# 1961                                                      10.021037
# 1962                                                      10.356112
# 1963                                                      10.703901
# 1964                                                      11.062585
# 1965                                                      11.431128
# 1966                                                      11.809022
# 1967                                                      12.197524
# 1968                                                      12.599491
# 1969                                                      13.018795
# 1970                                                      13.458216
# ...

# %%
df['1960'].mean()
# Out:
# nan

# %%
df.loc[["Zimbabwe"]]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Zimbabwe              ZWE  Population density (people per sq. km of land ...
#
#              Indicator Code  1960       1961       1962       1963       1964  \
# Country Name
# Zimbabwe        EN.POP.DNST   NaN  10.021037  10.356112  10.703901  11.062585
#
#                    1965       1966  ...       2007       2008      2009  \
# Country Name                        ...
# Zimbabwe      11.431128  11.809022  ...  34.374559  34.885516  35.46852
#
#                    2010       2011       2012       2013       2014  \
# Country Name
# Zimbabwe      36.122262  36.850438  37.651498  38.511289  39.410249
#
#                    2015  2016
# Country Name
# Zimbabwe      40.332819   NaN
#
# [1 rows x 60 columns]

# %%
df.loc[["Zimbabwe","Greece"]]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Zimbabwe              ZWE  Population density (people per sq. km of land ...
# Greece                GRC  Population density (people per sq. km of land ...
#
#              Indicator Code  1960       1961       1962       1963       1964  \
# Country Name
# Zimbabwe        EN.POP.DNST   NaN  10.021037  10.356112  10.703901  11.062585
# Greece          EN.POP.DNST   NaN  65.151668  65.540985  65.784523  66.023499
#
#                    1965       1966  ...       2007       2008       2009  \
# Country Name                        ...
# Zimbabwe      11.431128  11.809022  ...  34.374559  34.885516  35.468520
# Greece        66.333072  66.824290  ...  85.713522  85.941358  86.167704
#
#                    2010       2011       2012       2013       2014  \
# Country Name
# Zimbabwe      36.122262  36.850438  37.651498  38.511289  39.410249
# ...

# %%
#subset of greece and india with years 1970/90
df.loc[["Zimbabwe","Greece"],["1970","1990"]]
# Out:
#                    1970       1990
# Country Name
# Zimbabwe      13.458216  27.102937
# Greece        68.214166  79.106222

# %%
#iterating the whole dataset
for index,row in df.iterrows():
    print(index,row)
# Out:
# Aruba Country Code                                                    ABW
# Indicator Name    Population density (people per sq. km of land ...
# Indicator Code                                          EN.POP.DNST
# 1960                                                            NaN
# 1961                                                     307.972222
# 1962                                                     312.366667
# 1963                                                     314.983333
# 1964                                                     316.827778
# 1965                                                     318.666667
# 1966                                                     320.622222
# 1967                                                     322.494444
# 1968                                                     324.361111
# 1969                                                     326.244444
# 1970                                                     328.138889
# ...

# %%
for index,row in df.iterrows():
    #only for printing the dataset until angola
    if index=='Angola':
        break
    print(index,'\n',row[["Country Code","1970","1990","2010"]],'\n')
# Out:
# Aruba
#  Country Code           ABW
# 1970            328.138889
# 1990            345.266667
# 2010            564.427778
# Name: Aruba, dtype: object
#
# Andorra
#  Country Code           AND
# 1970             51.657447
# 1990            115.980851
# 2010            179.614894
# Name: Andorra, dtype: object
#
# Afghanistan
#  Country Code          AFG
# 1970            17.034429
# 1990            18.484162
# 2010            42.830327
# Name: Afghanistan, dtype: object
